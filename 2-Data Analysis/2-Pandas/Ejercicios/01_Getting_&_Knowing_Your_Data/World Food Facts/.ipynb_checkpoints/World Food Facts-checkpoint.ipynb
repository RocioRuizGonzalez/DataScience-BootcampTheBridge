# %% [markdown]
# # Ex1 - Getting and knowing your Data

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ###  Step 2. Download the dataset to your computer and unzip it.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
food= pd.read_csv('./food_100.csv', sep=',', index_col='code')
food
# Out:
#        Unnamed: 0                                                url  \
# code
# 3087            0  http://world-en.openfoodfacts.org/product/0000...
# 4530            1  http://world-en.openfoodfacts.org/product/0000...
# 4559            2  http://world-en.openfoodfacts.org/product/0000...
# 16087           3  http://world-en.openfoodfacts.org/product/0000...
# 16094           4  http://world-en.openfoodfacts.org/product/0000...
# ...           ...                                                ...
# 34715          95  http://world-en.openfoodfacts.org/product/0000...
# 34784          96  http://world-en.openfoodfacts.org/product/0000...
# 34791          97  http://world-en.openfoodfacts.org/product/0000...
# 35071          98  http://world-en.openfoodfacts.org/product/0000...
# 35170          99  http://world-en.openfoodfacts.org/product/0000...
#
#                           creator   created_t      created_datetime  \
# code
# 3087   openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 4530              usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 4559              usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 16087             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 16094             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                           ...         ...                   ...
# 34715             usda-ndb-import  1489055715  2017-03-09T10:35:15Z
# 34784             usda-ndb-import  1489138485  2017-03-10T09:34:45Z
# 34791             usda-ndb-import  1489055720  2017-03-09T10:35:20Z
# 35071             usda-ndb-import  1489138484  2017-03-10T09:34:44Z
# 35170             usda-ndb-import  1489138488  2017-03-10T09:34:48Z
#
#        last_modified_t last_modified_datetime                    product_name  \
# code
# 3087        1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 4530        1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 4559        1489069957   2017-03-09T14:32:37Z                         Peanuts
# 16087       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 16094       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
# ...                ...                    ...                             ...
# 34715       1489055715   2017-03-09T10:35:15Z            Organic Pecan Halves
# 34784       1489138485   2017-03-10T09:34:45Z    Unsalted Dry Roasted Almonds
# 34791       1489055720   2017-03-09T10:35:20Z       Organic Raw Pumpkin Seeds
# 35071       1489138484   2017-03-10T09:34:44Z  Organic Extra Virgin Olive Oil
# 35170       1489138488   2017-03-10T09:34:48Z                   Liquid Aminos
#
#        generic_name quantity  ... fruits-vegetables-nuts_100g  \
# code                          ...
# 3087            NaN      1kg  ...                         NaN
# 4530            NaN      NaN  ...                         NaN
# 4559            NaN      NaN  ...                         NaN
# 16087           NaN      NaN  ...                         NaN
# 16094           NaN      NaN  ...                         NaN
# ...             ...      ...  ...                         ...
# 34715           NaN      NaN  ...                         NaN
# 34784           NaN      NaN  ...                         NaN
# 34791           NaN      NaN  ...                         NaN
# 35071           NaN      NaN  ...                         NaN
# 35170           NaN      NaN  ...                         NaN
#
#       fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# code
# 3087                                   NaN                              NaN
# 4530                                   NaN                              NaN
# 4559                                   NaN                              NaN
# 16087                                  NaN                              NaN
# 16094                                  NaN                              NaN
# ...                                    ...                              ...
# 34715                                  NaN                              NaN
# 34784                                  NaN                              NaN
# 34791                                  NaN                              NaN
# 35071                                  NaN                              NaN
# 35170                                  NaN                              NaN
#
#       cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# code
# 3087         NaN             NaN                   NaN
# 4530         NaN             NaN                   NaN
# 4559         NaN             NaN                   NaN
# 16087        NaN             NaN                   NaN
# 16094        NaN             NaN                   NaN
# ...          ...             ...                   ...
# 34715        NaN             NaN                   NaN
# 34784        NaN             NaN                   NaN
# 34791        NaN             NaN                   NaN
# 35071        NaN             NaN                   NaN
# 35170        NaN             NaN                   NaN
#
#       nutrition-score-fr_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# code
# 3087                      NaN                      NaN                  NaN
# 4530                     14.0                     14.0                  NaN
# 4559                      0.0                      0.0                  NaN
# 16087                    12.0                     12.0                  NaN
# 16094                     NaN                      NaN                  NaN
# ...                       ...                      ...                  ...
# 34715                     NaN                      NaN                  NaN
# 34784                     NaN                      NaN                  NaN
# 34791                    12.0                     12.0                  NaN
# 35071                     NaN                      NaN                  NaN
# 35170                     NaN                      NaN                  NaN
#
#        water-hardness_100g
# code
# 3087                   NaN
# 4530                   NaN
# 4559                   NaN
# 16087                  NaN
# 16094                  NaN
# ...                    ...
# 34715                  NaN
# 34784                  NaN
# 34791                  NaN
# 35071                  NaN
# 35170                  NaN
#
# [100 rows x 163 columns]

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head(5)
# Out:
#        Unnamed: 0                                                url  \
# code
# 3087            0  http://world-en.openfoodfacts.org/product/0000...
# 4530            1  http://world-en.openfoodfacts.org/product/0000...
# 4559            2  http://world-en.openfoodfacts.org/product/0000...
# 16087           3  http://world-en.openfoodfacts.org/product/0000...
# 16094           4  http://world-en.openfoodfacts.org/product/0000...
#
#                           creator   created_t      created_datetime  \
# code
# 3087   openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 4530              usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 4559              usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 16087             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 16094             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#        last_modified_t last_modified_datetime                    product_name  \
# code
# 3087        1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 4530        1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 4559        1489069957   2017-03-09T14:32:37Z                         Peanuts
# 16087       1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 16094       1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#        generic_name quantity  ... fruits-vegetables-nuts_100g  \
# code                          ...
# 3087            NaN      1kg  ...                         NaN
# 4530            NaN      NaN  ...                         NaN
# 4559            NaN      NaN  ...                         NaN
# 16087           NaN      NaN  ...                         NaN
# 16094           NaN      NaN  ...                         NaN
#
#       fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# code
# 3087                                   NaN                              NaN
# 4530                                   NaN                              NaN
# 4559                                   NaN                              NaN
# 16087                                  NaN                              NaN
# 16094                                  NaN                              NaN
#
#       cocoa_100g chlorophyl_100g carbon-footprint_100g  \
# code
# 3087         NaN             NaN                   NaN
# 4530         NaN             NaN                   NaN
# 4559         NaN             NaN                   NaN
# 16087        NaN             NaN                   NaN
# 16094        NaN             NaN                   NaN
#
#       nutrition-score-fr_100g  nutrition-score-uk_100g  glycemic-index_100g  \
# code
# 3087                      NaN                      NaN                  NaN
# 4530                     14.0                     14.0                  NaN
# 4559                      0.0                      0.0                  NaN
# 16087                    12.0                     12.0                  NaN
# 16094                     NaN                      NaN                  NaN
#
#        water-hardness_100g
# code
# 3087                   NaN
# 4530                   NaN
# 4559                   NaN
# 16087                  NaN
# 16094                  NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
len(food)
# Out:
# 100

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.shape[1]
# Out:
# 163

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['Unnamed: 0', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[105]
# Out:
# '-fructose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.iloc[::,105].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# Int64Index([ 3087,  4530,  4559, 16087, 16094, 16100, 16117, 16124, 16193,
#             16513, 16612, 16650, 16872, 16933, 17497, 18012, 18050, 18173,
#             18197, 18227, 18265, 18289, 18319, 18340, 18357, 18371, 18388,
#             18395, 18401, 18418, 18449, 18456, 18500, 18517, 18524, 18555,
#             18562, 18579, 18630, 18708, 18753, 18760, 18869, 18883, 18937,
#             18944, 20114, 24600, 27083, 27205, 30038, 30113, 30540, 30557,
#             30564, 30571, 30595, 30625, 30649, 30717, 30724, 31097, 31141,
#             31172, 31233, 31288, 32070, 32117, 32384, 32858, 32896, 33015,
#             33060, 33084, 33268, 33503, 33572, 33589, 33626, 33640, 33657,
#             33664, 33688, 34135, 34142, 34241, 34265, 34425, 34432, 34449,
#             34456, 34470, 34548, 34562, 34623, 34715, 34784, 34791, 35071,
#             35170],
#            dtype='int64', name='code')

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food[["product_name"]].iloc[19]
# Out:
# product_name    Organic Oat Groats
# Name: 18227, dtype: object

# %%
food.iloc[19][["product_name"]]
# Out:
# product_name    Organic Oat Groats
# Name: 18227, dtype: object

# %%
food.columns
# Out:
# Index(['Unnamed: 0', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
list(food.columns)
# Out:
# ['Unnamed: 0',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
#  'ingredients_that_may_be_from_palm_oil_n',
#  'ingredients_that_may_be_from_palm_oil',
#  'ingredients_that_may_be_from_palm_oil_tags',
#  'nutrition_grade_uk',
#  'nutrition_grade_fr',
#  'pnns_groups_1',
#  'pnns_groups_2',
#  'states',
#  'states_tags',
#  'states_en',
#  'main_category',
#  'main_category_en',
#  'image_url',
#  'image_small_url',
#  'energy_100g',
#  'energy-from-fat_100g',
#  'fat_100g',
#  'saturated-fat_100g',
#  '-butyric-acid_100g',
#  '-caproic-acid_100g',
#  '-caprylic-acid_100g',
#  '-capric-acid_100g',
#  '-lauric-acid_100g',
#  '-myristic-acid_100g',
#  '-palmitic-acid_100g',
#  '-stearic-acid_100g',
#  '-arachidic-acid_100g',
#  '-behenic-acid_100g',
#  '-lignoceric-acid_100g',
#  '-cerotic-acid_100g',
#  '-montanic-acid_100g',
#  '-melissic-acid_100g',
#  'monounsaturated-fat_100g',
#  'polyunsaturated-fat_100g',
#  'omega-3-fat_100g',
#  '-alpha-linolenic-acid_100g',
#  '-eicosapentaenoic-acid_100g',
#  '-docosahexaenoic-acid_100g',
#  'omega-6-fat_100g',
#  '-linoleic-acid_100g',
#  '-arachidonic-acid_100g',
#  '-gamma-linolenic-acid_100g',
#  '-dihomo-gamma-linolenic-acid_100g',
#  'omega-9-fat_100g',
#  '-oleic-acid_100g',
#  '-elaidic-acid_100g',
#  '-gondoic-acid_100g',
#  '-mead-acid_100g',
#  '-erucic-acid_100g',
#  '-nervonic-acid_100g',
#  'trans-fat_100g',
#  'cholesterol_100g',
#  'carbohydrates_100g',
#  'sugars_100g',
#  '-sucrose_100g',
#  '-glucose_100g',
#  '-fructose_100g',
#  '-lactose_100g',
#  '-maltose_100g',
#  '-maltodextrins_100g',
#  'starch_100g',
#  'polyols_100g',
#  'fiber_100g',
#  'proteins_100g',
#  'casein_100g',
#  'serum-proteins_100g',
#  'nucleotides_100g',
#  'salt_100g',
#  'sodium_100g',
#  'alcohol_100g',
#  'vitamin-a_100g',
#  'beta-carotene_100g',
#  'vitamin-d_100g',
#  'vitamin-e_100g',
#  'vitamin-k_100g',
#  'vitamin-c_100g',
#  'vitamin-b1_100g',
#  'vitamin-b2_100g',
#  'vitamin-pp_100g',
#  'vitamin-b6_100g',
#  'vitamin-b9_100g',
#  'folates_100g',
#  'vitamin-b12_100g',
#  'biotin_100g',
#  'pantothenic-acid_100g',
#  'silica_100g',
#  'bicarbonate_100g',
#  'potassium_100g',
#  'chloride_100g',
#  'calcium_100g',
#  'phosphorus_100g',
#  'iron_100g',
#  'magnesium_100g',
#  'zinc_100g',
#  'copper_100g',
#  'manganese_100g',
#  'fluoride_100g',
#  'selenium_100g',
#  'chromium_100g',
#  'molybdenum_100g',
#  'iodine_100g',
#  'caffeine_100g',
#  'taurine_100g',
#  'ph_100g',
#  'fruits-vegetables-nuts_100g',
#  'fruits-vegetables-nuts-estimate_100g',
#  'collagen-meat-protein-ratio_100g',
#  'cocoa_100g',
#  'chlorophyl_100g',
#  'carbon-footprint_100g',
#  'nutrition-score-fr_100g',
#  'nutrition-score-uk_100g',
#  'glycemic-index_100g',
#  'water-hardness_100g']

# %%
list(food.columns).index("product_name")
# Out:
# 7

# %%
food.iloc[19,7]
# Out:
# 'Organic Oat Groats'
